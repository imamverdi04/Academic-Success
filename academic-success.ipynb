# %%
import pandas as pd
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV, cross_validate
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
pd.set_option('display.max_columns',None)
pd.set_option('display.width',500)

# %%
df=pd.read_csv('/kaggle/input/playground-series-s4e6/train.csv')
df
# Out:
#           id  Marital status  Application mode  Application order  Course  Daytime/evening attendance  Previous qualification  Previous qualification (grade)  Nacionality  Mother's qualification  Father's qualification  Mother's occupation  Father's occupation  Admission grade  Displaced  Educational special needs  Debtor  Tuition fees up to date  Gender  Scholarship holder  Age at enrollment  International  Curricular units 1st sem (credited)  Curricular units 1st sem (enrolled)  \
# 0          0               1                 1                  1    9238                           1                       1                           126.0            1                       1                      19                    5                    5            122.6          0                          0       0                        1       0                   1                 18              0                                    0                                    6
# ...

# %%
df.shape
# Out:
# (76518, 38)

# %%
dt = pd.read_csv('/kaggle/input/playground-series-s4e6/test.csv')
X_test = dt.drop(['id'],axis=1)
X_test.head()
# Out:
#    Marital status  Application mode  Application order  Course  Daytime/evening attendance  Previous qualification  Previous qualification (grade)  Nacionality  Mother's qualification  Father's qualification  Mother's occupation  Father's occupation  Admission grade  Displaced  Educational special needs  Debtor  Tuition fees up to date  Gender  Scholarship holder  Age at enrollment  International  Curricular units 1st sem (credited)  Curricular units 1st sem (enrolled)  \
# 0               1                 1                  1    9500                           1                       1                           141.0            1                       3                       1                    2                    3            152.1          0                          0       0                        0       0                   0                 18              0                                    0                                    7
# ...

# %%
X_test.shape
# Out:
# (51012, 36)

# %%
le_gender = LabelEncoder()
df['Target_encoded'] = le_gender.fit_transform(df['Target'])
df
# Out:
#           id  Marital status  Application mode  Application order  Course  Daytime/evening attendance  Previous qualification  Previous qualification (grade)  Nacionality  Mother's qualification  Father's qualification  Mother's occupation  Father's occupation  Admission grade  Displaced  Educational special needs  Debtor  Tuition fees up to date  Gender  Scholarship holder  Age at enrollment  International  Curricular units 1st sem (credited)  Curricular units 1st sem (enrolled)  \
# 0          0               1                 1                  1    9238                           1                       1                           126.0            1                       1                      19                    5                    5            122.6          0                          0       0                        1       0                   1                 18              0                                    0                                    6
# ...

# %%
df['Target'].unique()
# Out:
# array(['Graduate', 'Dropout', 'Enrolled'], dtype=object)

# %%
y_train=df['Target_encoded']
X_train=df.drop(['id','Target','Target_encoded'],axis=1)

# %%
X_train
# Out:
#        Marital status  Application mode  Application order  Course  Daytime/evening attendance  Previous qualification  Previous qualification (grade)  Nacionality  Mother's qualification  Father's qualification  Mother's occupation  Father's occupation  Admission grade  Displaced  Educational special needs  Debtor  Tuition fees up to date  Gender  Scholarship holder  Age at enrollment  International  Curricular units 1st sem (credited)  Curricular units 1st sem (enrolled)  \
# 0                   1                 1                  1    9238                           1                       1                           126.0            1                       1                      19                    5                    5            122.6          0                          0       0                        1       0                   1                 18              0                                    0                                    6
# ...

# %%
df.isnull().sum()
# Out:
# id                                                0
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance                        0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76518 entries, 0 to 76517
# Data columns (total 39 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   id                                              76518 non-null  int64
#  1   Marital status                                  76518 non-null  int64
#  2   Application mode                                76518 non-null  int64
#  3   Application order                               76518 non-null  int64
#  4   Course                                          76518 non-null  int64
#  5   Daytime/evening attendance                      76518 non-null  int64
#  6   Previous qualification                          76518 non-null  int64
#  7   Previous qualification (grade)                  76518 non-null  float64
#  8   Nacionality                                     76518 non-null  int64
# ...

# %%
X_train_scaled = StandardScaler().fit_transform(X_train)

# %%
X_train=X_train_scaled

# %%
knn_model = KNeighborsClassifier().fit(X_train,y_train)
y_train_pred=knn_model.predict(X_train)

# %%
y_train_pred
# Out:
# array([2, 0, 0, ..., 0, 0, 2])

# %%
print(classification_report(y_train,y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87     25296
#            1       0.69      0.62      0.65     14940
#            2       0.86      0.92      0.89     36282
#
#     accuracy                           0.84     76518
#    macro avg       0.81      0.80      0.80     76518
# weighted avg       0.84      0.84      0.84     76518

# %%
#test prediction

# %%
X_test_scaled = StandardScaler().fit_transform(X_test)
X_test=X_test_scaled

# %%
 y_test_pred = knn_model.predict(X_test)

# %%
y_test_pred
# Out:
# array([0, 2, 1, ..., 0, 0, 0])

# %%
X_test = dt.drop(['id'],axis=1)
X_test.head()
# Out:
#    Marital status  Application mode  Application order  Course  Daytime/evening attendance  Previous qualification  Previous qualification (grade)  Nacionality  Mother's qualification  Father's qualification  Mother's occupation  Father's occupation  Admission grade  Displaced  Educational special needs  Debtor  Tuition fees up to date  Gender  Scholarship holder  Age at enrollment  International  Curricular units 1st sem (credited)  Curricular units 1st sem (enrolled)  \
# 0               1                 1                  1    9500                           1                       1                           141.0            1                       3                       1                    2                    3            152.1          0                          0       0                        0       0                   0                 18              0                                    0                                    7
# ...

# %%
y_test_pred
# Out:
# array([0, 2, 1, ..., 0, 0, 0])

# %%
X_test.shape
# Out:
# (51012, 36)

# %%
y_test_pred = pd.Series(y_test_pred, name='target')
y_test_pred
# Out:
# 0        0
# 1        2
# 2        1
# 3        2
# 4        1
#         ..
# 51007    0
# 51008    0
# 51009    0
# 51010    0
# 51011    0
# Name: target, Length: 51012, dtype: int64

# %%
X_test
# Out:
#        Marital status  Application mode  Application order  Course  Daytime/evening attendance  Previous qualification  Previous qualification (grade)  Nacionality  Mother's qualification  Father's qualification  Mother's occupation  Father's occupation  Admission grade  Displaced  Educational special needs  Debtor  Tuition fees up to date  Gender  Scholarship holder  Age at enrollment  International  Curricular units 1st sem (credited)  Curricular units 1st sem (enrolled)  \
# 0                   1                 1                  1    9500                           1                       1                           141.0            1                       3                       1                    2                    3            152.1          0                          0       0                        0       0                   0                 18              0                                    0                                    7
# ...

# %%
X_test['target']=y_test_pred

# %%
X_test.head()
# Out:
#    Marital status  Application mode  Application order  Course  Daytime/evening attendance  Previous qualification  Previous qualification (grade)  Nacionality  Mother's qualification  Father's qualification  Mother's occupation  Father's occupation  Admission grade  Displaced  Educational special needs  Debtor  Tuition fees up to date  Gender  Scholarship holder  Age at enrollment  International  Curricular units 1st sem (credited)  Curricular units 1st sem (enrolled)  \
# 0               1                 1                  1    9500                           1                       1                           141.0            1                       3                       1                    2                    3            152.1          0                          0       0                        0       0                   0                 18              0                                    0                                    7
# ...

# %%
education_mapping = {
    0: 'Dropout',
    1: 'Enrolled',
    2: 'Graduate'
}

# Map encoded values to original categorical values
X_test['Education_Decoded'] = X_test['target'].map(education_mapping)

print("Decoded DataFrame:")
X_test
# Out:
# Decoded DataFrame:
#        Marital status  Application mode  Application order  Course  Daytime/evening attendance  Previous qualification  Previous qualification (grade)  Nacionality  Mother's qualification  Father's qualification  Mother's occupation  Father's occupation  Admission grade  Displaced  Educational special needs  Debtor  Tuition fees up to date  Gender  Scholarship holder  Age at enrollment  International  Curricular units 1st sem (credited)  Curricular units 1st sem (enrolled)  \
# 0                   1                 1                  1    9500                           1                       1                           141.0            1                       3                       1                    2                    3            152.1          0                          0       0                        0       0                   0                 18              0                                    0                                    7
# ...

# %%
submission = pd.read_csv('/kaggle/input/playground-series-s4e6/sample_submission.csv')

# %%
submission['Target']=X_test['Education_Decoded'].values

# %%
submission
# Out:
#            id    Target
# 0       76518   Dropout
# 1       76519  Graduate
# 2       76520  Enrolled
# 3       76521  Graduate
# 4       76522  Enrolled
# ...       ...       ...
# 51007  127525   Dropout
# 51008  127526   Dropout
# 51009  127527   Dropout
# 51010  127528   Dropout
# 51011  127529   Dropout
#
# [51012 rows x 2 columns]
